# %% [markdown]
# # Getting Financial Data - Pandas Datareader

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

import pandas_datareader.data as web

import datetime as dt

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is).

# %%
start = pd.to_datetime('2015-01-01')
end = pd.to_datetime('today')

# %% [markdown]
# ### Step 3. Get an API key for one of the APIs that are supported by Pandas Datareader, preferably for AlphaVantage.
#
# If you do not have an API key for any of the supported APIs, it is easiest to get one for [AlphaVantage](https://www.alphavantage.co/support/#api-key). (Note that the API key is shown directly after the signup. You do *not* receive it via e-mail.)
#
# (For a full list of the APIs that are supported by Pandas Datareader, [see here](https://pydata.github.io/pandas-datareader/readers/index.html). As the APIs are provided by third parties, this list may change.)

# %% [markdown]
# ### Step 4. Use Pandas Datarader to read the daily time series for the Apple stock (ticker symbol AAPL) between 01/01/2015 and today, assign it to df_apple and print it.

# %%
api_key = '29QW2Y2HCO1FQ4UM'
df_apple = web.DataReader("AAPL", "av-daily", start, end, api_key=api_key)
print(df_apple.head())
print(df_apple.tail())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File f:\Anaconda\envs\Python311\Lib\site-packages\pandas_datareader\av\__init__.py:72, in AlphaVantage._read_lines(self, out)
#      71 try:
# ---> 72     df = pd.DataFrame.from_dict(out[self.data_key], orient="index")
#      73 except KeyError:
#
# KeyError: 'Time Series (Daily)'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# Cell In[8], line 2
#       1 api_key = '29QW2Y2HCO1FQ4UM'
# ----> 2 df_apple = web.DataReader("AAPL", "av-daily", start, end, api_key=api_key)
#       3 print(df_apple.head())
#       4 print(df_apple.tail())
#
# File f:\Anaconda\envs\Python311\Lib\site-packages\pandas\util\_decorators.py:213, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     211         raise TypeError(msg)
#     212     kwargs[new_arg_name] = new_arg_value
# --> 213 return func(*args, **kwargs)
#
# File f:\Anaconda\envs\Python311\Lib\site-packages\pandas_datareader\data.py:577, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     556     return AVTimeSeriesReader(
#     557         symbols=name,
#     558         function="FX_DAILY",
#    (...)    564         api_key=api_key,
#     565     ).read()
#     567 elif data_source == "av-daily":
#     568     return AVTimeSeriesReader(
#     569         symbols=name,
#     570         function="TIME_SERIES_DAILY",
#     571         start=start,
#     572         end=end,
#     573         retry_count=retry_count,
#     574         pause=pause,
#     575         session=session,
#     576         api_key=api_key,
# --> 577     ).read()
#     579 elif data_source == "av-daily-adjusted":
#     580     return AVTimeSeriesReader(
#     581         symbols=name,
#     582         function="TIME_SERIES_DAILY_ADJUSTED",
#    (...)    588         api_key=api_key,
#     589     ).read()
#
# File f:\Anaconda\envs\Python311\Lib\site-packages\pandas_datareader\base.py:101, in _BaseReader.read(self)
#      99 """Read data from connector"""
#     100 try:
# --> 101     return self._read_one_data(self.url, self.params)
#     102 finally:
#     103     self.close()
#
# File f:\Anaconda\envs\Python311\Lib\site-packages\pandas_datareader\base.py:113, in _BaseReader._read_one_data(self, url, params)
#     111 else:
#     112     raise NotImplementedError(self._format)
# --> 113 return self._read_lines(out)
#
# File f:\Anaconda\envs\Python311\Lib\site-packages\pandas_datareader\av\time_series.py:114, in AVTimeSeriesReader._read_lines(self, out)
#     113 def _read_lines(self, out):
# --> 114     data = super(AVTimeSeriesReader, self)._read_lines(out)
#     115     # reverse since alphavantage returns descending by date
#     116     data = data[::-1]
#
# File f:\Anaconda\envs\Python311\Lib\site-packages\pandas_datareader\av\__init__.py:81, in AlphaVantage._read_lines(self, out)
#      75         raise ValueError(
#      76             "The requested symbol {} could not be "
#      77             "retrieved. Check valid ticker"
#      78             ".".format(self.symbols)
#      79         )
#      80     else:
# ---> 81         raise RemoteDataError(
#      82             " Their was an issue from the data vendor "
#      83             "side, here is their response: {}".format(out)
#      84         )
#      85 df = df[sorted(df.columns)]
#      86 df.columns = [id[3:] for id in df.columns]
#
# RemoteDataError:  Their was an issue from the data vendor side, here is their response: {'Information': 'Thank you for using Alpha Vantage! The outputsize=full parameter value is a premium feature for the TIME_SERIES_INTRADAY and TIME_SERIES_DAILY endpoints. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium features'}

# %% [markdown]
# ### Step 5. Add a new column "stock" to the dataframe and add the ticker symbol

# %%
df_apple['stock'] = 'AAPL'
print(df_apple.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_apple['stock'] = 'AAPL'
#       2 print(df_apple.head())
#
# NameError: name 'df_apple' is not defined

# %% [markdown]
# ### Step 6. Repeat the two previous steps for a few other stocks, always creating a new dataframe: Tesla, IBM and Microsoft. (Ticker symbols TSLA, IBM and MSFT.)

# %% [markdown]
# ### Step 7. Combine the four separate dataFrames into one combined dataFrame df that holds the information for all four stocks

# %% [markdown]
# ### Step 8. Shift the stock column into the index (making it a multi-level index consisting of the ticker symbol and the date).

# %% [markdown]
# ### Step 7. Create a dataFrame called vol, with the volume values.

# %% [markdown]
# ### Step 8. Aggregate the data of volume to weekly.
# Hint: Be careful to not sum data from the same week of 2015 and other years.

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015
